# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df= pd.read_csv('pair_nulos.csv',index_col = 0)

# %%
df.head(2)
# Out:
#        country  density abbreviation  agriculturalland  landarea  \
# 0  Afghanistan     60.0           AF              58.1  652230.0
# 1      Albania    105.0           AL              43.1   28748.0
#
#    armedforcessize  birthrate  callingcode capital/majorcity  co2-emissions  \
# 0         323000.0      32.49         93.0             Kabul         8672.0
# 1           9000.0      11.78        355.0            Tirana         4536.0
#
#       cpi  cpichange currency-code  fertilityrate  forestedarea  \
# 0  149.90        2.3           AFN           4.47           2.1
# 1  119.05        1.4           ALL           1.62          28.1
#
#    gasolineprice           gdp  grossprimaryeducationenrollment  \
# 0           0.70  1.910135e+10                            104.0
# 1           1.36  1.527808e+10                            107.0
#
#    grosstertiaryeducationenrollment  infantmortality largestcity  \
# 0                               9.7             47.9       Kabul
# ...

# %% [markdown]
# 1. Calcula las siguientes estadísticas descriptivas para las variables numéricas:
# Media
# Mediana
# Desviación estándar
# Mínimo
# Máximo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, 0 to 194
# Data columns (total 36 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            195 non-null    object
#  1   density                            195 non-null    float64
#  2   abbreviation                       188 non-null    object
#  3   agriculturalland                   188 non-null    float64
#  4   landarea                           194 non-null    float64
#  5   armedforcessize                    171 non-null    float64
#  6   birthrate                          189 non-null    float64
#  7   callingcode                        194 non-null    float64
#  8   capital/majorcity                  192 non-null    object
#  9   co2-emissions                      188 non-null    float64
#  10  cpi                                178 non-null    float64
# ...

# %%
# Extraer y ordenar la información por tipo de datos
df_numericas = df.select_dtypes(include = ["number"])
df_numericas.dtypes
# Out:
# density                              float64
# agriculturalland                     float64
# landarea                             float64
# armedforcessize                      float64
# birthrate                            float64
# callingcode                          float64
# co2-emissions                        float64
# cpi                                  float64
# cpichange                            float64
# fertilityrate                        float64
# forestedarea                         float64
# gasolineprice                        float64
# gdp                                  float64
# grossprimaryeducationenrollment      float64
# grosstertiaryeducationenrollment     float64
# infantmortality                      float64
# lifeexpectancy                       float64
# maternalmortalityratio               float64
# minimumwage                          float64
# outofpockethealthexpenditure         float64
# physiciansperthousand                float64
# ...

# %%
lista_numericas=[]
for x in df_numericas.columns:
    lista_numericas.append(x)
    

print(lista_numericas)
resultados = df[lista_numericas].agg(['mean', 'median', 'var', 'std', 'max'])
resultados
# Out:
# ['density', 'agriculturalland', 'landarea', 'armedforcessize', 'birthrate', 'callingcode', 'co2-emissions', 'cpi', 'cpichange', 'fertilityrate', 'forestedarea', 'gasolineprice', 'gdp', 'grossprimaryeducationenrollment', 'grosstertiaryeducationenrollment', 'infantmortality', 'lifeexpectancy', 'maternalmortalityratio', 'minimumwage', 'outofpockethealthexpenditure', 'physiciansperthousand', 'population', 'populationlaborforceparticipation', 'taxrevenue', 'totaltaxrate', 'unemploymentrate', 'urban_population', 'lattitude', 'longitude']
#              density  agriculturalland      landarea  armedforcessize  \
# mean    3.567641e+02         39.117553  6.896244e+05     1.592749e+05
# median  8.900000e+01         39.600000  1.195110e+05     3.100000e+04
# var     3.931849e+06        474.501348  3.692582e+12     1.448783e+11
# std     1.982889e+03         21.783052  1.921609e+06     3.806288e+05
# max     2.633700e+04         82.600000  1.709824e+07     3.031000e+06
#
# ...

# %% [markdown]
# 2. Identifica el país con la mayor densidad de población y el país con la menor población en el conjunto de datos.

# %%
df.head(2)
# Out:
#        country  density abbreviation  agriculturalland  landarea  \
# 0  Afghanistan     60.0           AF              58.1  652230.0
# 1      Albania    105.0           AL              43.1   28748.0
#
#    armedforcessize  birthrate  callingcode capital/majorcity  co2-emissions  \
# 0         323000.0      32.49         93.0             Kabul         8672.0
# 1           9000.0      11.78        355.0            Tirana         4536.0
#
#       cpi  cpichange currency-code  fertilityrate  forestedarea  \
# 0  149.90        2.3           AFN           4.47           2.1
# 1  119.05        1.4           ALL           1.62          28.1
#
#    gasolineprice           gdp  grossprimaryeducationenrollment  \
# 0           0.70  1.910135e+10                            104.0
# 1           1.36  1.527808e+10                            107.0
#
#    grosstertiaryeducationenrollment  infantmortality largestcity  \
# 0                               9.7             47.9       Kabul
# ...

# %%
# Encuentra el país con la mayor densidad de población
pais_max_densidad = df.loc[df['density'].idxmax(), 'country']
max_densidad = df['density'].max()


print(f"País con mayor densidad de población: {pais_max_densidad} (Densidad: {max_densidad} personas por km²)")
# Out:
# País con mayor densidad de población: Monaco (Densidad: 26337.0 personas por km²)

# %%
# Encuentra el país con la mayor densidad de población
pais_min_densidad = df.loc[df['density'].idxmin(), 'country']
min_densidad = df['density'].min()


print(f"País con menor densidad de población: {pais_min_densidad} (Densidad: {min_densidad} personas por km²)")
# Out:
# País con menor densidad de población: Mongolia (Densidad: 2.0 personas por km²)

# %% [markdown]
# 3. Calcula la tasa promedio de natalidad (birth_rate) para todos los países en el conjunto de datos.

# %%
df.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agriculturalland', 'landarea',
#        'armedforcessize', 'birthrate', 'callingcode', 'capital/majorcity',
#        'co2-emissions', 'cpi', 'cpichange', 'currency-code', 'fertilityrate',
#        'forestedarea', 'gasolineprice', 'gdp',
#        'grossprimaryeducationenrollment', 'grosstertiaryeducationenrollment',
#        'infantmortality', 'largestcity', 'lifeexpectancy',
#        'maternalmortalityratio', 'minimumwage', 'officiallanguage',
#        'outofpockethealthexpenditure', 'physiciansperthousand', 'population',
#        'populationlaborforceparticipation', 'taxrevenue', 'totaltaxrate',
#        'unemploymentrate', 'urban_population', 'lattitude', 'longitude',
#        'continente'],
#       dtype='object')

# %%
media_natalidad = df['birthrate'].mean()
print(f'La tasa promedio de natalidad para todos los países es de {round(media_natalidad,2)}')
# Out:
# La tasa promedio de natalidad para todos los países es de 20.21

# %% [markdown]
# 4. Realiza un análisis de la mortalidad infantil (infant_mortality) y clasifica los países en tres categorías: baja, moderada y alta mortalidad infantil. Belen

# %%
# Definir los límites para las categorías
baja = 10  
moderada = 20
alta =30
df.loc[df['infantmortality'] < baja, 'mortalidad_infantil_categoria'] = 'Baja'
if moderada is not None:
    df.loc[df['infantmortality'] > moderada, 'mortalidad_infantil_categoria'] = 'Moderada'
if alta is not None:
    df.loc[df['infantmortality'] > alta, 'mortalidad_infantil_categoria'] = 'Alta'
df.head(2)
# Out:
#        country  density abbreviation  agriculturalland  landarea  \
# 0  Afghanistan     60.0           AF              58.1  652230.0
# 1      Albania    105.0           AL              43.1   28748.0
#
#    armedforcessize  birthrate  callingcode capital/majorcity  co2-emissions  \
# 0         323000.0      32.49         93.0             Kabul         8672.0
# 1           9000.0      11.78        355.0            Tirana         4536.0
#
#       cpi  cpichange currency-code  fertilityrate  forestedarea  \
# 0  149.90        2.3           AFN           4.47           2.1
# 1  119.05        1.4           ALL           1.62          28.1
#
#    gasolineprice           gdp  grossprimaryeducationenrollment  \
# 0           0.70  1.910135e+10                            104.0
# 1           1.36  1.527808e+10                            107.0
#
#    grosstertiaryeducationenrollment  infantmortality largestcity  \
# 0                               9.7             47.9       Kabul
# ...

# %%
# Mostrar los resultados
print(df[['country', 'infantmortality', 'mortalidad_infantil_categoria']])
# Out:
#          country  infantmortality mortalidad_infantil_categoria
# 0    Afghanistan             47.9                          Alta
# 1        Albania              7.8                          Baja
# 2        Algeria             20.1                      Moderada
# 3        Andorra              2.7                          Baja
# 4         Angola             51.6                          Alta
# ..           ...              ...                           ...
# 190    Venezuela             21.4                      Moderada
# 191      Vietnam             16.5                           nan
# 192        Yemen             42.9                          Alta
# 193       Zambia             40.4                          Alta
# 194     Zimbabwe             33.9                          Alta
#
# [195 rows x 3 columns]

# %%
conteo_categorias = df['mortalidad_infantil_categoria'].value_counts()
plt.bar(conteo_categorias.index, conteo_categorias)

plt.xlabel('Categoría de Mortalidad Infantil')
plt.ylabel('Número de Países')
plt.title('Distribución de Mortalidad Infantil por Categoría')
plt.show()

# %% [markdown]
# 6. Visualiza la distribución de la variable "cpi" utilizando un histograma y comenta sobre la distribución de los índices de percepción de corrupción.

# %%
plt.hist(df['cpi'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Índice de Percepción de Corrupción (CPI)')
plt.ylabel('Frecuencia')
plt.title('Distribución del Índice de Percepción de Corrupción')

plt.show()

# %% [markdown]
# 8. Calcula el porcentaje promedio de personas que participan en la fuerza laboral(population_labor_force_participation) para todos los países.

# %%
porcentaje_promedio = df['populationlaborforceparticipation'].mean()

print(f"El porcentaje promedio de participación en la fuerza laboral es: {round(porcentaje_promedio,2)}%")


colores = ['lightblue' if x != 'populationlaborforceparticipation' else 'gold' for x in df.columns]

plt.bar(['Participación en la fuerza laboral', 'Otros'], [porcentaje_promedio, 100 - porcentaje_promedio])

plt.title('Porcentaje Promedio de Participación en la Fuerza Laboral')
plt.ylabel('Porcentaje')

plt.show()
# Out:
# El porcentaje promedio de participación en la fuerza laboral es: 62.74%
